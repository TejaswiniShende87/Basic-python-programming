# %%
#arithmetic operators

# %%
a = 10
b = 3

# %%
#addition

# %%
a + b
# Out:
# 13

# %%
#subtraction

# %%
a - b
# Out:
# 7

# %%
#multiplication

# %%
a * b
# Out:
# 30

# %%
#division

# %%
a/b
# Out:
# 3.3333333333333335

# %%
#modulus

# %%
a%b
# Out:
# 1

# %%
#floor division

# %%
a//b
# Out:
# 3

# %%
# Comparison Operators

# %%
x = 5
y = 10

# %%
# Equal to

# %%
x == y
# Out:
# False

# %%
# Not equal to

# %%
x != y
# Out:
# True

# %%
# Greater than

# %%
x > y
# Out:
# False

# %%
# Less than

# %%
x < y
# Out:
# True

# %%
# Greater than or equal to

# %%
x >= y
# Out:
# False

# %%
# Less than or equal to

# %%
x <= y
# Out:
# True

# %%
# Logical Operators

# %%
# and: Returns True only if both conditions are true.
# or: Returns True if at least one condition is true.
# not: Reverses the result, inverting True to False and vice versa.

# %%
a = True
b = False

# %%
#AND

# %%
a and b
# Out:
# False

# %%
#OR

# %%
a or b
# Out:
# True

# %%
#NOT

# %%
not a
# Out:
# False

# %%
# Assignment Operators

# %%
x = 5

# %%
# x = x + 3

# %%
x += 3

# %%
x
# Out:
# 8

# %%
# x = x - 2

# %%
x -= 2

# %%
x
# Out:
# 6

# %%
# x = x * 4

# %%
x *= 4

# %%
x
# Out:
# 24

# %%
# x = x / 2

# %%
x /= 2

# %%
x
# Out:
# 12.0

# %%
# Membership Operators

# %%
fruits = ["apple", "banana", "mango"]

# %%
"apple" in fruits
# Out:
# True

# %%
"grapes" not in fruits
# Out:
# True

# %%
# Identity Operators

# %%
a = [1, 2, 3]
b = a
c = [1, 2, 3]

# %%
# True

# %%
a is b
# Out:
# True

# %%
# False

# %%
a is c
# Out:
# False

# %%
# True

# %%
a is not c
# Out:
# True

# %%
# Bitwise Operators

# %%
a = 5
b = 3

# %%
# AND

# %%
a & b
# Out:
# 1

# %%
# OR

# %%
a | b
# Out:
# 7

# %%
# XOR

# %%
a ^ b
# Out:
# 6

# %%
# NOT

# %%
~a
# Out:
# -6

# %%
# Left Shift

# %%
a << 1
# Out:
# 10

# %%
# Right Shift

# %%
a >> 1
# Out:
# 2
